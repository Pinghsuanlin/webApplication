# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **1.Read json feeds from the Webhose file**

# %%
#Print the JSON object schema
df1 = pd.read_json('D:\Spring2022Codes\webhose_apple.json', lines=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10800 entries, 0 to 10799
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   thread                10800 non-null  object
#  1   uuid                  10800 non-null  object
#  2   url                   10800 non-null  object
#  3   ord_in_thread         10800 non-null  int64
#  4   parent_url            0 non-null      float64
#  5   author                10800 non-null  object
#  6   published             10800 non-null  object
#  7   title                 10800 non-null  object
#  8   text                  10800 non-null  object
#  9   highlightText         10800 non-null  object
#  10  highlightTitle        10800 non-null  object
#  11  highlightThreadTitle  10800 non-null  object
#  12  language              10800 non-null  object
#  13  external_links        10800 non-null  object
#  14  external_images       10800 non-null  object
# ...

# %%
#Print the count of JSON objects in the collection
len(df1)
# Out:
# 10800

# %%
#Have an idea on how the webhose dataset looks
df1.head()
# Out:
#                                               thread  \
# 0  {'uuid': '958670c1717dd8f1edbe33369ee12469c1ca...
# 1  {'uuid': '4aa124a2c78843f8404405e65cd69da7bfae...
# 2  {'uuid': '26ebb8ab008ed759d017994376326cc50809...
# 3  {'uuid': 'cb43510b88a39af756c8744572f3f6e91155...
# 4  {'uuid': 'cfe464ff046a7ad47b3fd6a13eac8eb7252d...
#
#                                        uuid  \
# 0  958670c1717dd8f1edbe33369ee12469c1cafdf1
# 1  4aa124a2c78843f8404405e65cd69da7bfaed9c4
# 2  26ebb8ab008ed759d017994376326cc508090c07
# 3  cb43510b88a39af756c8744572f3f6e9115566ce
# 4  cfe464ff046a7ad47b3fd6a13eac8eb7252d03e6
#
#                                                  url  ord_in_thread  \
# 0  http://omgili.com/ri/.wHSUbtEfZRyyLJKogCgQjT1s...              0
# 1  http://omgili.com/ri/.wHSUbtEfZQVWCSCAg0UcdNr5...              0
# 2  http://omgili.com/ri/.wHSUbtEfZQr3Bw_O2_O6hJpn...              0
# 3  http://omgili.com/ri/.wHSUbtEfZS9pZjbkz0yttu0H...              0
# ...

# %% [markdown]
# # **2. Read entries from Crunchbase CSV file**

# %%
#Print the CSV schema
df = pd.read_csv('D:\Spring2022Codes\cb_sample.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  99 non-null     object
#  1   city                  74 non-null     object
#  2   region                74 non-null     object
#  3   country               80 non-null     object
#  4   category_list         99 non-null     object
#  5   category_groups_list  99 non-null     object
#  6   cb_url                99 non-null     object
#  7   rank                  99 non-null     int64
#  8   domain                99 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 7.1+ KB

# %%
#Print the count of entries in the collection
len(df)
# Out:
# 99

# %%
#Have an idea on how the crunchbase dataset looks
df.head()
# Out:
#               name         city            region country  \
# 0         Eventige     New York          New York      US
# 1          Eventik  Mexico City  Distrito Federal      MX
# 2          Eventil          NaN               NaN     NaN
# 3  Eventiles, Inc.      Seattle        Washington      US
# 4        Eventilio        Delhi             Delhi      IN
#
#                                        category_list  \
# 0  Advertising,Brand Marketing,Digital Marketing,...
# 1                             Mobile,Music,Ticketing
# 2  Events,Information Services,Information Techno...
# 3                                           Software
# 4                                                iOS
#
#                                 category_groups_list  \
# 0  Advertising,Commerce and Shopping,Information ...
# 1  Events,Media and Entertainment,Mobile,Music an...
# 2  Events,Information Technology,Media and Entert...
# 3                                           Software
# ...

# %% [markdown]
# # **3. Implement Flask API functions**

# %%
#Return a list of Crunchbase companies based in New York
#!pip install flask
from flask import Flask, render_template #this will give the same template
app = Flask("cb_ny")

# %%
@app.route('/')
def show_cb_ny():
    global df
    line = df[df['city'] == 'New York']['name'].tolist()
    return render_template('index.html', result=line)     
    #return output

# %%
app.run(host='localhost', port=4021)

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app "cb_ny" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://localhost:4021/ (Press CTRL+C to quit)
# 127.0.0.1 - - [10/Feb/2022 10:14:19] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Feb/2022 10:14:19] "GET /favicon.ico HTTP/1.1" 404 -

# %%
#verify the result is the same as it supposed to be
print(df[df['city'] == 'New York']['name'].tolist())

# %%
#Take a user input through an API endpoint to return a list of JSON objects from Webhose file 
#where the "title" fields contain the query string
from flask import Flask, request, render_template
app2 = Flask("webhose")

@app.route('/')
def my_form():
    return render_template("my-form.html")

@app.route('/', methods=['POST'])
def my_form_post():
    global df1
    val = request.form['userinput']  #feature of the requests library
    val = val.lower()
    line = df1[df1['title'].str.contains(val)
    return str(line)

app.run(host='localhost', port=5021)

if webhose == "__main__":  #entry point #dunder methods
    app.run(debug=True)
